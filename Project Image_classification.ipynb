# %% [markdown]
# # Cells with # ToDO have to be completed

# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).
#
# ## Data
# CIFAR-10  is an established computer-vision dataset used for object recognition. It is a subset of the 80 million tiny images dataset and consists of 60,000 32x32 color images containing one of 10 object classes, with 6000 images per class. It was collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton.

# %% [markdown]
# Let's get the data by running the following function

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %% [markdown]
# ## The following are some helper functions students can use in their code

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer


def _load_label_names():
    """
    Load the label names from file
    """
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


def load_cfar10_batch(cifar10_dataset_folder_path, batch_id):
    """
    Load a batch of the dataset
    """
    with open(cifar10_dataset_folder_path + '/data_batch_' + str(batch_id), mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')

    features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    labels = batch['labels']

    return features, labels


def display_stats(cifar10_dataset_folder_path, batch_id, sample_id):
    """
    Display Stats of the the dataset
    """
    batch_ids = list(range(1, 6))

    if batch_id not in batch_ids:
        print('Batch Id out of Range. Possible Batch Ids: {}'.format(batch_ids))
        return None

    features, labels = load_cfar10_batch(cifar10_dataset_folder_path, batch_id)

    if not (0 <= sample_id < len(features)):
        print('{} samples in batch {}.  {} is out of range.'.format(len(features), batch_id, sample_id))
        return None

    print('\nStats of batch {}:'.format(batch_id))
    print('Samples: {}'.format(len(features)))
    print('Label Counts: {}'.format(dict(zip(*np.unique(labels, return_counts=True)))))
    print('First 20 Labels: {}'.format(labels[:20]))

    sample_image = features[sample_id]
    sample_label = labels[sample_id]
    label_names = _load_label_names()

    print('\nExample of Image {}:'.format(sample_id))
    print('Image - Min Value: {} Max Value: {}'.format(sample_image.min(), sample_image.max()))
    print('Image - Shape: {}'.format(sample_image.shape))
    print('Label - Label Id: {} Name: {}'.format(sample_label, label_names[sample_label]))
    plt.axis('off')
    plt.imshow(sample_image)


def _preprocess_and_save(normalize, one_hot_encode, features, labels, filename):
    """
    Preprocess data and save it to file
    """
    features = normalize(features)
    labels = one_hot_encode(labels)

    pickle.dump((features, labels), open(filename, 'wb'))


def preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode):
    """
    Preprocess Training and Validation Data
    """
    n_batches = 5
    valid_features = []
    valid_labels = []

    for batch_i in range(1, n_batches + 1):
        features, labels = load_cfar10_batch(cifar10_dataset_folder_path, batch_i)
        validation_count = int(len(features) * 0.1)

        # Prprocess and save a batch of training data
        _preprocess_and_save(
            normalize,
            one_hot_encode,
            features[:-validation_count],
            labels[:-validation_count],
            'preprocess_batch_' + str(batch_i) + '.p')

        # Use a portion of training batch for validation
        valid_features.extend(features[-validation_count:])
        valid_labels.extend(labels[-validation_count:])

    # Preprocess and Save all validation data
    _preprocess_and_save(
        normalize,
        one_hot_encode,
        np.array(valid_features),
        np.array(valid_labels),
        'preprocess_validation.p')

    with open(cifar10_dataset_folder_path + '/test_batch', mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')

    # load the training data
    test_features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    test_labels = batch['labels']

    # Preprocess and Save all training data
    _preprocess_and_save(
        normalize,
        one_hot_encode,
        np.array(test_features),
        np.array(test_labels),
        'preprocess_training.p')


def batch_features_labels(features, labels, batch_size):
    """
    Split features and labels into batches
    """
    for start in range(0, len(features), batch_size):
        end = min(start + batch_size, len(features))
        yield features[start:end], labels[start:end]


def load_preprocess_training_batch(batch_id, batch_size):
    """
    Load the Preprocessed Training data and return them in batches of <batch_size> or less
    """
    filename = 'preprocess_batch_' + str(batch_id) + '.p'
    features, labels = pickle.load(open(filename, mode='rb'))

    # Return the training data in batches of size <batch_size> or less
    return batch_features_labels(features, labels, batch_size)


def display_image_predictions(features, labels, predictions):
    n_classes = 10
    label_names = _load_label_names()
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(range(n_classes))
    label_ids = label_binarizer.inverse_transform(np.array(labels))

    fig, axies = plt.subplots(nrows=4, ncols=2)
    fig.tight_layout()
    fig.suptitle('Softmax Predictions', fontsize=20, y=1.1)

    n_predictions = 3
    margin = 0.05
    ind = np.arange(n_predictions)
    width = (1. - 2. * margin) / n_predictions

    for image_i, (feature, label_id, pred_indicies, pred_values) in enumerate(zip(features, label_ids, predictions.indices, predictions.values)):
        pred_names = [label_names[pred_i] for pred_i in pred_indicies]
        correct_name = label_names[label_id]

        axies[image_i][0].imshow(feature*255)
        axies[image_i][0].set_title(correct_name)
        axies[image_i][0].set_axis_off()

        axies[image_i][1].barh(ind + margin, pred_values[::-1], width)
        axies[image_i][1].set_yticks(ind + margin)
        axies[image_i][1].set_yticklabels(pred_names[::-1])
        axies[image_i][1].set_xticks([0, 0.5, 1.0])

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 5000
display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 5000:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# # Solution (Not to be shared with students upfront)

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
# ToDO
import numpy as np
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    
    min_val = np.min(x)
    max_val = np.max(x)
    output = (x-min_val)/(max_val-min_val)
    return output

# %% [markdown]
# ### One-hot encode
# We'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.

# %%
# ToDO
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(range(10))
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    encoded = np.zeros((len(x), 10))
    
    for idx, val in enumerate(x):
        encoded[idx][val] = 1
        
    return encoded

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %%
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
# ToDO
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape = (None, image_shape[0], image_shape[1], image_shape[2]), name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape = (None, n_classes), name = 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # ToDO
    return tf.placeholder(tf.float32, name="keep_prob")


tf.reset_default_graph()

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    shape_of_x_tensor = x_tensor.get_shape().as_list()
    F_W = tf.Variable(tf.truncated_normal([conv_ksize[0] ,conv_ksize[1] ,shape_of_x_tensor[-1] ,conv_num_outputs] 
                                          ,dtype=tf.float32, stddev=0.2))
    F_b = tf.Variable(tf.zeros([conv_num_outputs]  ,dtype=tf.float32))
    strides_conv = [1, conv_strides[0], conv_strides[1], 1]
    padding = 'SAME'
    output = tf.nn.conv2d(x_tensor, F_W, strides_conv, padding)
    output = tf.nn.bias_add(output, F_b)
    output = tf.nn.relu(output)
    ksize_maxpool = [1, pool_ksize[0], pool_ksize[1], 1]
    strides_maxpool = [1, pool_strides[0], pool_strides[1], 1]
    output = tf.nn.max_pool(output, ksize_maxpool, strides_maxpool, padding)
    
    return output

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
# ToDO
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    return tf.contrib.layers.flatten(x_tensor)

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
# ToDO
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
   
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn=tf.nn.relu)

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    shape = x_tensor.get_shape().as_list()
    weights= tf.Variable(tf.truncated_normal([shape[1], num_outputs] ,dtype=tf.float32, stddev=0.2))
    biases = tf.Variable(tf.zeros([num_outputs]  ,dtype=tf.float32))
    out = tf.add(tf.matmul(x_tensor, weights), biases)
    return out

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
# ToDO
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """

    out = conv2d_maxpool(x, conv_num_outputs = 16, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 32, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 64, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))

    # Function Definition from Above:
    out = flatten(out)
    
    # ToDO
    # call fully_conn function with 64,32,16 num_outputs, along with dropout after each full_conn, and final output with 10 num_outputs

    fully_conn1 = fully_conn(out,num_outputs=64)#64
    fully_conn1 = tf.nn.dropout(fully_conn1, keep_prob) # dropout
    fully_conn1 =  fully_conn(fully_conn1,num_outputs=32)#32
    fully_conn1 = tf.nn.dropout(fully_conn1, keep_prob) # dropout# dropout
    fully_conn1 =  fully_conn(fully_conn1,num_outputs=32) # 16
    fully_conn1 = tf.nn.dropout(fully_conn1, keep_prob) # dropout# dropout #dropout
    out = output(fully_conn1,num_outputs=10) #10 
    
    return out


##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch,keep_prob:keep_probability})

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    train_acc = sess.run(accuracy, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    train_cost = sess.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    print('Cost {::>8.5f}, Accuracy on Training {:.4f} -'
                  'Validation Accuracy: {:.4f}'.format(
                train_cost,
                train_acc,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
epochs = 50
batch_size = 256
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.30261, Accuracy on Training 0.1000 -Validation Accuracy: 0.1070
# Epoch  2, CIFAR-10 Batch 1:  Cost :2.29975, Accuracy on Training 0.1000 -Validation Accuracy: 0.0912
# Epoch  3, CIFAR-10 Batch 1:  Cost :2.29401, Accuracy on Training 0.2000 -Validation Accuracy: 0.1426
# Epoch  4, CIFAR-10 Batch 1:  Cost :2.28254, Accuracy on Training 0.0750 -Validation Accuracy: 0.1522
# Epoch  5, CIFAR-10 Batch 1:  Cost :2.24132, Accuracy on Training 0.1500 -Validation Accuracy: 0.2022
# Epoch  6, CIFAR-10 Batch 1:  Cost :2.20821, Accuracy on Training 0.1250 -Validation Accuracy: 0.2052
# Epoch  7, CIFAR-10 Batch 1:  Cost :2.15827, Accuracy on Training 0.0750 -Validation Accuracy: 0.1894
# Epoch  8, CIFAR-10 Batch 1:  Cost :2.08814, Accuracy on Training 0.1250 -Validation Accuracy: 0.1942
# Epoch  9, CIFAR-10 Batch 1:  Cost :2.04573, Accuracy on Training 0.1500 -Validation Accuracy: 0.2106
# Epoch 10, CIFAR-10 Batch 1:  Cost :2.03695, Accuracy on Training 0.2250 -Validation Accuracy: 0.2154
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.99630, Accuracy on Training 0.2000 -Validation Accuracy: 0.2346
# Epoch 12, CIFAR-10 Batch 1:  Cost :1.94946, Accuracy on Training 0.2500 -Validation Accuracy: 0.2228
# Epoch 13, CIFAR-10 Batch 1:  Cost :1.91914, Accuracy on Training 0.2500 -Validation Accuracy: 0.2246
# Epoch 14, CIFAR-10 Batch 1:  Cost :1.85620, Accuracy on Training 0.2250 -Validation Accuracy: 0.2460
# Epoch 15, CIFAR-10 Batch 1:  Cost :1.87576, Accuracy on Training 0.2500 -Validation Accuracy: 0.2528
# Epoch 16, CIFAR-10 Batch 1:  Cost :1.81426, Accuracy on Training 0.3000 -Validation Accuracy: 0.2794
# Epoch 17, CIFAR-10 Batch 1:  Cost :1.77838, Accuracy on Training 0.2500 -Validation Accuracy: 0.2726
# Epoch 18, CIFAR-10 Batch 1:  Cost :1.76509, Accuracy on Training 0.2500 -Validation Accuracy: 0.2834
# Epoch 19, CIFAR-10 Batch 1:  Cost :1.72749, Accuracy on Training 0.2250 -Validation Accuracy: 0.2694
# Epoch 20, CIFAR-10 Batch 1:  Cost :1.70786, Accuracy on Training 0.2500 -Validation Accuracy: 0.2878
# Epoch 21, CIFAR-10 Batch 1:  Cost :1.67626, Accuracy on Training 0.2750 -Validation Accuracy: 0.2726
# Epoch 22, CIFAR-10 Batch 1:  Cost :1.67187, Accuracy on Training 0.2500 -Validation Accuracy: 0.2810
# Epoch 23, CIFAR-10 Batch 1:  Cost :1.64733, Accuracy on Training 0.3000 -Validation Accuracy: 0.2812
# Epoch 24, CIFAR-10 Batch 1:  Cost :1.63596, Accuracy on Training 0.3250 -Validation Accuracy: 0.2822
# Epoch 25, CIFAR-10 Batch 1:  Cost :1.61924, Accuracy on Training 0.3000 -Validation Accuracy: 0.2818
# Epoch 26, CIFAR-10 Batch 1:  Cost :1.64255, Accuracy on Training 0.3000 -Validation Accuracy: 0.2748
# Epoch 27, CIFAR-10 Batch 1:  Cost :1.60188, Accuracy on Training 0.2750 -Validation Accuracy: 0.2860
# Epoch 28, CIFAR-10 Batch 1:  Cost :1.62250, Accuracy on Training 0.3500 -Validation Accuracy: 0.2778
# Epoch 29, CIFAR-10 Batch 1:  Cost :1.57377, Accuracy on Training 0.3000 -Validation Accuracy: 0.2924
# Epoch 30, CIFAR-10 Batch 1:  Cost :1.57460, Accuracy on Training 0.2500 -Validation Accuracy: 0.2772
# Epoch 31, CIFAR-10 Batch 1:  Cost :1.54987, Accuracy on Training 0.2750 -Validation Accuracy: 0.2864
# Epoch 32, CIFAR-10 Batch 1:  Cost :1.56044, Accuracy on Training 0.2000 -Validation Accuracy: 0.2862
# Epoch 33, CIFAR-10 Batch 1:  Cost :1.55570, Accuracy on Training 0.3250 -Validation Accuracy: 0.2870
# Epoch 34, CIFAR-10 Batch 1:  Cost :1.54871, Accuracy on Training 0.3500 -Validation Accuracy: 0.2930
# Epoch 35, CIFAR-10 Batch 1:  Cost :1.53968, Accuracy on Training 0.3000 -Validation Accuracy: 0.2942
# Epoch 36, CIFAR-10 Batch 1:  Cost :1.51341, Accuracy on Training 0.4500 -Validation Accuracy: 0.2858
# Epoch 37, CIFAR-10 Batch 1:  Cost :1.51482, Accuracy on Training 0.4000 -Validation Accuracy: 0.2864
# Epoch 38, CIFAR-10 Batch 1:  Cost :1.49182, Accuracy on Training 0.4000 -Validation Accuracy: 0.2900
# Epoch 39, CIFAR-10 Batch 1:  Cost :1.49329, Accuracy on Training 0.3250 -Validation Accuracy: 0.2900
# Epoch 40, CIFAR-10 Batch 1:  Cost :1.47721, Accuracy on Training 0.3750 -Validation Accuracy: 0.2914
# Epoch 41, CIFAR-10 Batch 1:  Cost :1.47151, Accuracy on Training 0.4000 -Validation Accuracy: 0.2918
# Epoch 42, CIFAR-10 Batch 1:  Cost :1.46941, Accuracy on Training 0.3750 -Validation Accuracy: 0.3000
# Epoch 43, CIFAR-10 Batch 1:  Cost :1.47881, Accuracy on Training 0.3750 -Validation Accuracy: 0.3044
# Epoch 44, CIFAR-10 Batch 1:  Cost :1.50408, Accuracy on Training 0.3500 -Validation Accuracy: 0.2998
# Epoch 45, CIFAR-10 Batch 1:  Cost :1.46588, Accuracy on Training 0.4250 -Validation Accuracy: 0.2958
# Epoch 46, CIFAR-10 Batch 1:  Cost :1.45786, Accuracy on Training 0.3250 -Validation Accuracy: 0.3074
# Epoch 47, CIFAR-10 Batch 1:  Cost :1.45148, Accuracy on Training 0.4500 -Validation Accuracy: 0.3012
# Epoch 48, CIFAR-10 Batch 1:  Cost :1.44794, Accuracy on Training 0.4500 -Validation Accuracy: 0.3060
# Epoch 49, CIFAR-10 Batch 1:  Cost :1.40688, Accuracy on Training 0.4000 -Validation Accuracy: 0.3072
# Epoch 50, CIFAR-10 Batch 1:  Cost :1.38188, Accuracy on Training 0.4000 -Validation Accuracy: 0.3176

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.30196, Accuracy on Training 0.0750 -Validation Accuracy: 0.0992
# Epoch  1, CIFAR-10 Batch 2:  Cost :2.29243, Accuracy on Training 0.1000 -Validation Accuracy: 0.1152
# Epoch  1, CIFAR-10 Batch 3:  Cost :2.27757, Accuracy on Training 0.1500 -Validation Accuracy: 0.1208
# Epoch  1, CIFAR-10 Batch 4:  Cost :2.24687, Accuracy on Training 0.1250 -Validation Accuracy: 0.1686
# Epoch  1, CIFAR-10 Batch 5:  Cost :2.23189, Accuracy on Training 0.2000 -Validation Accuracy: 0.1638
# Epoch  2, CIFAR-10 Batch 1:  Cost :2.28643, Accuracy on Training 0.1000 -Validation Accuracy: 0.1354
# Epoch  2, CIFAR-10 Batch 2:  Cost :2.31666, Accuracy on Training 0.0500 -Validation Accuracy: 0.1028
# Epoch  2, CIFAR-10 Batch 3:  Cost :2.18328, Accuracy on Training 0.2250 -Validation Accuracy: 0.1670
# Epoch  2, CIFAR-10 Batch 4:  Cost :2.13466, Accuracy on Training 0.1250 -Validation Accuracy: 0.1776
# Epoch  2, CIFAR-10 Batch 5:  Cost :2.13391, Accuracy on Training 0.2250 -Validation Accuracy: 0.2032
# Epoch  3, CIFAR-10 Batch 1:  Cost :2.21894, Accuracy on Training 0.1000 -Validation Accuracy: 0.1816
# Epoch  3, CIFAR-10 Batch 2:  Cost :2.09913, Accuracy on Training 0.2750 -Validation Accuracy: 0.2002
# Epoch  3, CIFAR-10 Batch 3:  Cost :1.93889, Accuracy on Training 0.2250 -Validation Accuracy: 0.1842
# Epoch  3, CIFAR-10 Batch 4:  Cost :2.00255, Accuracy on Training 0.2000 -Validation Accuracy: 0.1818
# Epoch  3, CIFAR-10 Batch 5:  Cost :2.03266, Accuracy on Training 0.3250 -Validation Accuracy: 0.2308
# Epoch  4, CIFAR-10 Batch 1:  Cost :2.12120, Accuracy on Training 0.2250 -Validation Accuracy: 0.2128
# Epoch  4, CIFAR-10 Batch 2:  Cost :2.03831, Accuracy on Training 0.2500 -Validation Accuracy: 0.2484
# Epoch  4, CIFAR-10 Batch 3:  Cost :1.86226, Accuracy on Training 0.3250 -Validation Accuracy: 0.2214
# Epoch  4, CIFAR-10 Batch 4:  Cost :1.97145, Accuracy on Training 0.2750 -Validation Accuracy: 0.2526
# Epoch  4, CIFAR-10 Batch 5:  Cost :1.94831, Accuracy on Training 0.3250 -Validation Accuracy: 0.2556
# Epoch  5, CIFAR-10 Batch 1:  Cost :2.04377, Accuracy on Training 0.2500 -Validation Accuracy: 0.2480
# Epoch  5, CIFAR-10 Batch 2:  Cost :1.98514, Accuracy on Training 0.3000 -Validation Accuracy: 0.2600
# Epoch  5, CIFAR-10 Batch 3:  Cost :1.70233, Accuracy on Training 0.3500 -Validation Accuracy: 0.2498
# Epoch  5, CIFAR-10 Batch 4:  Cost :1.90805, Accuracy on Training 0.2250 -Validation Accuracy: 0.2754
# Epoch  5, CIFAR-10 Batch 5:  Cost :1.88897, Accuracy on Training 0.2750 -Validation Accuracy: 0.2630
# Epoch  6, CIFAR-10 Batch 1:  Cost :1.99281, Accuracy on Training 0.3000 -Validation Accuracy: 0.2490
# Epoch  6, CIFAR-10 Batch 2:  Cost :1.91623, Accuracy on Training 0.2750 -Validation Accuracy: 0.2802
# Epoch  6, CIFAR-10 Batch 3:  Cost :1.60889, Accuracy on Training 0.4250 -Validation Accuracy: 0.2786
# Epoch  6, CIFAR-10 Batch 4:  Cost :1.83657, Accuracy on Training 0.2500 -Validation Accuracy: 0.2844
# Epoch  6, CIFAR-10 Batch 5:  Cost :1.82310, Accuracy on Training 0.2250 -Validation Accuracy: 0.2944
# Epoch  7, CIFAR-10 Batch 1:  Cost :1.87909, Accuracy on Training 0.3250 -Validation Accuracy: 0.2886
# Epoch  7, CIFAR-10 Batch 2:  Cost :1.82042, Accuracy on Training 0.3000 -Validation Accuracy: 0.2922
# Epoch  7, CIFAR-10 Batch 3:  Cost :1.51230, Accuracy on Training 0.4500 -Validation Accuracy: 0.2928
# Epoch  7, CIFAR-10 Batch 4:  Cost :1.79079, Accuracy on Training 0.3000 -Validation Accuracy: 0.2930
# Epoch  7, CIFAR-10 Batch 5:  Cost :1.78295, Accuracy on Training 0.3000 -Validation Accuracy: 0.2980
# Epoch  8, CIFAR-10 Batch 1:  Cost :1.82559, Accuracy on Training 0.3750 -Validation Accuracy: 0.3068
# Epoch  8, CIFAR-10 Batch 2:  Cost :1.76845, Accuracy on Training 0.3000 -Validation Accuracy: 0.3212
# Epoch  8, CIFAR-10 Batch 3:  Cost :1.42906, Accuracy on Training 0.4250 -Validation Accuracy: 0.3190
# Epoch  8, CIFAR-10 Batch 4:  Cost :1.74959, Accuracy on Training 0.2750 -Validation Accuracy: 0.3210
# Epoch  8, CIFAR-10 Batch 5:  Cost :1.70482, Accuracy on Training 0.3250 -Validation Accuracy: 0.3344
# Epoch  9, CIFAR-10 Batch 1:  Cost :1.76101, Accuracy on Training 0.4250 -Validation Accuracy: 0.3302
# Epoch  9, CIFAR-10 Batch 2:  Cost :1.70052, Accuracy on Training 0.3750 -Validation Accuracy: 0.3366
# Epoch  9, CIFAR-10 Batch 3:  Cost :1.39870, Accuracy on Training 0.5000 -Validation Accuracy: 0.3440
# Epoch  9, CIFAR-10 Batch 4:  Cost :1.66881, Accuracy on Training 0.3000 -Validation Accuracy: 0.3544
# Epoch  9, CIFAR-10 Batch 5:  Cost :1.70097, Accuracy on Training 0.3750 -Validation Accuracy: 0.3418
# Epoch 10, CIFAR-10 Batch 1:  Cost :1.68874, Accuracy on Training 0.4250 -Validation Accuracy: 0.3608
# Epoch 10, CIFAR-10 Batch 2:  Cost :1.68902, Accuracy on Training 0.3750 -Validation Accuracy: 0.3558
# Epoch 10, CIFAR-10 Batch 3:  Cost :1.42112, Accuracy on Training 0.4500 -Validation Accuracy: 0.3460
# Epoch 10, CIFAR-10 Batch 4:  Cost :1.61211, Accuracy on Training 0.2500 -Validation Accuracy: 0.3726
# Epoch 10, CIFAR-10 Batch 5:  Cost :1.65079, Accuracy on Training 0.4000 -Validation Accuracy: 0.3644
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.70148, Accuracy on Training 0.4250 -Validation Accuracy: 0.3446
# Epoch 11, CIFAR-10 Batch 2:  Cost :1.59396, Accuracy on Training 0.3750 -Validation Accuracy: 0.3700
# Epoch 11, CIFAR-10 Batch 3:  Cost :1.32943, Accuracy on Training 0.5000 -Validation Accuracy: 0.3776
# Epoch 11, CIFAR-10 Batch 4:  Cost :1.56538, Accuracy on Training 0.3250 -Validation Accuracy: 0.3682
# Epoch 11, CIFAR-10 Batch 5:  Cost :1.62589, Accuracy on Training 0.4000 -Validation Accuracy: 0.3798
# Epoch 12, CIFAR-10 Batch 1:  Cost :1.64301, Accuracy on Training 0.4250 -Validation Accuracy: 0.3660
# Epoch 12, CIFAR-10 Batch 2:  Cost :1.64157, Accuracy on Training 0.3500 -Validation Accuracy: 0.3556
# Epoch 12, CIFAR-10 Batch 3:  Cost :1.32698, Accuracy on Training 0.5750 -Validation Accuracy: 0.3850
# Epoch 12, CIFAR-10 Batch 4:  Cost :1.50444, Accuracy on Training 0.3250 -Validation Accuracy: 0.3718
# Epoch 12, CIFAR-10 Batch 5:  Cost :1.62465, Accuracy on Training 0.3750 -Validation Accuracy: 0.3736
# Epoch 13, CIFAR-10 Batch 1:  Cost :1.58215, Accuracy on Training 0.5000 -Validation Accuracy: 0.3734
# Epoch 13, CIFAR-10 Batch 2:  Cost :1.55777, Accuracy on Training 0.3250 -Validation Accuracy: 0.3796
# Epoch 13, CIFAR-10 Batch 3:  Cost :1.24490, Accuracy on Training 0.5750 -Validation Accuracy: 0.3998
# Epoch 13, CIFAR-10 Batch 4:  Cost :1.49444, Accuracy on Training 0.4250 -Validation Accuracy: 0.3916
# Epoch 13, CIFAR-10 Batch 5:  Cost :1.53886, Accuracy on Training 0.3250 -Validation Accuracy: 0.4012
# Epoch 14, CIFAR-10 Batch 1:  Cost :1.47025, Accuracy on Training 0.5000 -Validation Accuracy: 0.4224
# Epoch 14, CIFAR-10 Batch 2:  Cost :1.45868, Accuracy on Training 0.3750 -Validation Accuracy: 0.4174
# Epoch 14, CIFAR-10 Batch 3:  Cost :1.25926, Accuracy on Training 0.6000 -Validation Accuracy: 0.4178
# Epoch 14, CIFAR-10 Batch 4:  Cost :1.45280, Accuracy on Training 0.4500 -Validation Accuracy: 0.4314
# Epoch 14, CIFAR-10 Batch 5:  Cost :1.44263, Accuracy on Training 0.5250 -Validation Accuracy: 0.4336
# Epoch 15, CIFAR-10 Batch 1:  Cost :1.46209, Accuracy on Training 0.5250 -Validation Accuracy: 0.4112
# Epoch 15, CIFAR-10 Batch 2:  Cost :1.46002, Accuracy on Training 0.3750 -Validation Accuracy: 0.4232
# Epoch 15, CIFAR-10 Batch 3:  Cost :1.16141, Accuracy on Training 0.6000 -Validation Accuracy: 0.4274
# Epoch 15, CIFAR-10 Batch 4:  Cost :1.41085, Accuracy on Training 0.4500 -Validation Accuracy: 0.4338
# Epoch 15, CIFAR-10 Batch 5:  Cost :1.43561, Accuracy on Training 0.5000 -Validation Accuracy: 0.4382
# Epoch 16, CIFAR-10 Batch 1:  Cost :1.41132, Accuracy on Training 0.5500 -Validation Accuracy: 0.4500
# Epoch 16, CIFAR-10 Batch 2:  Cost :1.43979, Accuracy on Training 0.3750 -Validation Accuracy: 0.4322
# Epoch 16, CIFAR-10 Batch 3:  Cost :1.14373, Accuracy on Training 0.6000 -Validation Accuracy: 0.4480
# Epoch 16, CIFAR-10 Batch 4:  Cost :1.36828, Accuracy on Training 0.5000 -Validation Accuracy: 0.4330
# Epoch 16, CIFAR-10 Batch 5:  Cost :1.43023, Accuracy on Training 0.3750 -Validation Accuracy: 0.4372
# Epoch 17, CIFAR-10 Batch 1:  Cost :1.34540, Accuracy on Training 0.6000 -Validation Accuracy: 0.4474
# Epoch 17, CIFAR-10 Batch 2:  Cost :1.43061, Accuracy on Training 0.4000 -Validation Accuracy: 0.4378
# Epoch 17, CIFAR-10 Batch 3:  Cost :1.11154, Accuracy on Training 0.6750 -Validation Accuracy: 0.4588
# Epoch 17, CIFAR-10 Batch 4:  Cost :1.25179, Accuracy on Training 0.5000 -Validation Accuracy: 0.4610
# Epoch 17, CIFAR-10 Batch 5:  Cost :1.28491, Accuracy on Training 0.6000 -Validation Accuracy: 0.4674
# Epoch 18, CIFAR-10 Batch 1:  Cost :1.36293, Accuracy on Training 0.6000 -Validation Accuracy: 0.4544
# Epoch 18, CIFAR-10 Batch 2:  Cost :1.34705, Accuracy on Training 0.4000 -Validation Accuracy: 0.4636
# Epoch 18, CIFAR-10 Batch 3:  Cost :1.07437, Accuracy on Training 0.6500 -Validation Accuracy: 0.4732
# Epoch 18, CIFAR-10 Batch 4:  Cost :1.24918, Accuracy on Training 0.5000 -Validation Accuracy: 0.4636
# Epoch 18, CIFAR-10 Batch 5:  Cost :1.27287, Accuracy on Training 0.6000 -Validation Accuracy: 0.4652
# Epoch 19, CIFAR-10 Batch 1:  Cost :1.32936, Accuracy on Training 0.5250 -Validation Accuracy: 0.4624
# Epoch 19, CIFAR-10 Batch 2:  Cost :1.28990, Accuracy on Training 0.4000 -Validation Accuracy: 0.4712
# Epoch 19, CIFAR-10 Batch 3:  Cost :1.09058, Accuracy on Training 0.7000 -Validation Accuracy: 0.4680
# Epoch 19, CIFAR-10 Batch 4:  Cost :1.19245, Accuracy on Training 0.5250 -Validation Accuracy: 0.4784
# Epoch 19, CIFAR-10 Batch 5:  Cost :1.24608, Accuracy on Training 0.6000 -Validation Accuracy: 0.4636
# Epoch 20, CIFAR-10 Batch 1:  Cost :1.21938, Accuracy on Training 0.7000 -Validation Accuracy: 0.4886
# Epoch 20, CIFAR-10 Batch 2:  Cost :1.19163, Accuracy on Training 0.4750 -Validation Accuracy: 0.4874
# Epoch 20, CIFAR-10 Batch 3:  Cost :1.03800, Accuracy on Training 0.6500 -Validation Accuracy: 0.4726
# Epoch 20, CIFAR-10 Batch 4:  Cost :1.21804, Accuracy on Training 0.4750 -Validation Accuracy: 0.4778
# Epoch 20, CIFAR-10 Batch 5:  Cost :1.26196, Accuracy on Training 0.5250 -Validation Accuracy: 0.4606
# Epoch 21, CIFAR-10 Batch 1:  Cost :1.22801, Accuracy on Training 0.6000 -Validation Accuracy: 0.4722
# Epoch 21, CIFAR-10 Batch 2:  Cost :1.20512, Accuracy on Training 0.5000 -Validation Accuracy: 0.4876
# Epoch 21, CIFAR-10 Batch 3:  Cost :1.03387, Accuracy on Training 0.6500 -Validation Accuracy: 0.4832
# Epoch 21, CIFAR-10 Batch 4:  Cost :1.14876, Accuracy on Training 0.5000 -Validation Accuracy: 0.4904
# Epoch 21, CIFAR-10 Batch 5:  Cost :1.21326, Accuracy on Training 0.5000 -Validation Accuracy: 0.4728
# Epoch 22, CIFAR-10 Batch 1:  Cost :1.14470, Accuracy on Training 0.6250 -Validation Accuracy: 0.4958
# Epoch 22, CIFAR-10 Batch 2:  Cost :1.14677, Accuracy on Training 0.4750 -Validation Accuracy: 0.4922
# Epoch 22, CIFAR-10 Batch 3:  Cost :0.95053, Accuracy on Training 0.7250 -Validation Accuracy: 0.4986
# Epoch 22, CIFAR-10 Batch 4:  Cost :1.18059, Accuracy on Training 0.5000 -Validation Accuracy: 0.4860
# Epoch 22, CIFAR-10 Batch 5:  Cost :1.18996, Accuracy on Training 0.5750 -Validation Accuracy: 0.4830
# Epoch 23, CIFAR-10 Batch 1:  Cost :1.12616, Accuracy on Training 0.6500 -Validation Accuracy: 0.4918
# Epoch 23, CIFAR-10 Batch 2:  Cost :1.14430, Accuracy on Training 0.5000 -Validation Accuracy: 0.5078
# Epoch 23, CIFAR-10 Batch 3:  Cost :0.92658, Accuracy on Training 0.7000 -Validation Accuracy: 0.5056
# Epoch 23, CIFAR-10 Batch 4:  Cost :1.09977, Accuracy on Training 0.6000 -Validation Accuracy: 0.4968
# Epoch 23, CIFAR-10 Batch 5:  Cost :1.17406, Accuracy on Training 0.6250 -Validation Accuracy: 0.4962
# Epoch 24, CIFAR-10 Batch 1:  Cost :1.11271, Accuracy on Training 0.6750 -Validation Accuracy: 0.5056
# Epoch 24, CIFAR-10 Batch 2:  Cost :1.09089, Accuracy on Training 0.5250 -Validation Accuracy: 0.5068
# Epoch 24, CIFAR-10 Batch 3:  Cost :0.97989, Accuracy on Training 0.6750 -Validation Accuracy: 0.5098
# Epoch 24, CIFAR-10 Batch 4:  Cost :1.13784, Accuracy on Training 0.5750 -Validation Accuracy: 0.4962
# Epoch 24, CIFAR-10 Batch 5:  Cost :1.19086, Accuracy on Training 0.5500 -Validation Accuracy: 0.4854
# Epoch 25, CIFAR-10 Batch 1:  Cost :1.09754, Accuracy on Training 0.7250 -Validation Accuracy: 0.4950
# Epoch 25, CIFAR-10 Batch 2:  Cost :1.06220, Accuracy on Training 0.5250 -Validation Accuracy: 0.5140
# Epoch 25, CIFAR-10 Batch 3:  Cost :0.91770, Accuracy on Training 0.7250 -Validation Accuracy: 0.5044
# Epoch 25, CIFAR-10 Batch 4:  Cost :1.06065, Accuracy on Training 0.6000 -Validation Accuracy: 0.5124
# Epoch 25, CIFAR-10 Batch 5:  Cost :1.10566, Accuracy on Training 0.6750 -Validation Accuracy: 0.5020
# Epoch 26, CIFAR-10 Batch 1:  Cost :1.08756, Accuracy on Training 0.7000 -Validation Accuracy: 0.4920
# Epoch 26, CIFAR-10 Batch 2:  Cost :1.01529, Accuracy on Training 0.6250 -Validation Accuracy: 0.5036
# Epoch 26, CIFAR-10 Batch 3:  Cost :0.92750, Accuracy on Training 0.7000 -Validation Accuracy: 0.4986
# Epoch 26, CIFAR-10 Batch 4:  Cost :1.13149, Accuracy on Training 0.6000 -Validation Accuracy: 0.4976
# Epoch 26, CIFAR-10 Batch 5:  Cost :1.09143, Accuracy on Training 0.6250 -Validation Accuracy: 0.5030
# Epoch 27, CIFAR-10 Batch 1:  Cost :1.07046, Accuracy on Training 0.6500 -Validation Accuracy: 0.5038
# Epoch 27, CIFAR-10 Batch 2:  Cost :0.95537, Accuracy on Training 0.5500 -Validation Accuracy: 0.5096
# Epoch 27, CIFAR-10 Batch 3:  Cost :0.88986, Accuracy on Training 0.7000 -Validation Accuracy: 0.5118
# Epoch 27, CIFAR-10 Batch 4:  Cost :1.09223, Accuracy on Training 0.6500 -Validation Accuracy: 0.5016
# Epoch 27, CIFAR-10 Batch 5:  Cost :1.09579, Accuracy on Training 0.6250 -Validation Accuracy: 0.5150
# Epoch 28, CIFAR-10 Batch 1:  Cost :1.05218, Accuracy on Training 0.6500 -Validation Accuracy: 0.5122
# Epoch 28, CIFAR-10 Batch 2:  Cost :0.97297, Accuracy on Training 0.5750 -Validation Accuracy: 0.5234
# Epoch 28, CIFAR-10 Batch 3:  Cost :0.91887, Accuracy on Training 0.7000 -Validation Accuracy: 0.4994
# Epoch 28, CIFAR-10 Batch 4:  Cost :1.07103, Accuracy on Training 0.6250 -Validation Accuracy: 0.5098
# Epoch 28, CIFAR-10 Batch 5:  Cost :1.03431, Accuracy on Training 0.7000 -Validation Accuracy: 0.5078
# Epoch 29, CIFAR-10 Batch 1:  Cost :1.03934, Accuracy on Training 0.6500 -Validation Accuracy: 0.5022
# Epoch 29, CIFAR-10 Batch 2:  Cost :1.00208, Accuracy on Training 0.5000 -Validation Accuracy: 0.5154
# Epoch 29, CIFAR-10 Batch 3:  Cost :0.88644, Accuracy on Training 0.7250 -Validation Accuracy: 0.5090
# Epoch 29, CIFAR-10 Batch 4:  Cost :1.05051, Accuracy on Training 0.5750 -Validation Accuracy: 0.5056
# Epoch 29, CIFAR-10 Batch 5:  Cost :1.01076, Accuracy on Training 0.6500 -Validation Accuracy: 0.5030
# Epoch 30, CIFAR-10 Batch 1:  Cost :0.99172, Accuracy on Training 0.6750 -Validation Accuracy: 0.5112
# Epoch 30, CIFAR-10 Batch 2:  Cost :0.98468, Accuracy on Training 0.6000 -Validation Accuracy: 0.5168
# Epoch 30, CIFAR-10 Batch 3:  Cost :0.87235, Accuracy on Training 0.7000 -Validation Accuracy: 0.5038
# Epoch 30, CIFAR-10 Batch 4:  Cost :1.03497, Accuracy on Training 0.5750 -Validation Accuracy: 0.5082
# Epoch 30, CIFAR-10 Batch 5:  Cost :1.02704, Accuracy on Training 0.6750 -Validation Accuracy: 0.5012
# Epoch 31, CIFAR-10 Batch 1:  Cost :1.01826, Accuracy on Training 0.6250 -Validation Accuracy: 0.5008
# Epoch 31, CIFAR-10 Batch 2:  Cost :0.92783, Accuracy on Training 0.6000 -Validation Accuracy: 0.5152
# Epoch 31, CIFAR-10 Batch 3:  Cost :0.86109, Accuracy on Training 0.7250 -Validation Accuracy: 0.5058
# Epoch 31, CIFAR-10 Batch 4:  Cost :1.00402, Accuracy on Training 0.6000 -Validation Accuracy: 0.5142
# Epoch 31, CIFAR-10 Batch 5:  Cost :0.98018, Accuracy on Training 0.7000 -Validation Accuracy: 0.5166
# Epoch 32, CIFAR-10 Batch 1:  Cost :0.97263, Accuracy on Training 0.6250 -Validation Accuracy: 0.5114
# Epoch 32, CIFAR-10 Batch 2:  Cost :0.96300, Accuracy on Training 0.5750 -Validation Accuracy: 0.5092
# Epoch 32, CIFAR-10 Batch 3:  Cost :0.81574, Accuracy on Training 0.7000 -Validation Accuracy: 0.5064
# Epoch 32, CIFAR-10 Batch 4:  Cost :0.98395, Accuracy on Training 0.6250 -Validation Accuracy: 0.5130
# Epoch 32, CIFAR-10 Batch 5:  Cost :0.98060, Accuracy on Training 0.7000 -Validation Accuracy: 0.5222
# Epoch 33, CIFAR-10 Batch 1:  Cost :0.96908, Accuracy on Training 0.7000 -Validation Accuracy: 0.5042
# Epoch 33, CIFAR-10 Batch 2:  Cost :0.98120, Accuracy on Training 0.5500 -Validation Accuracy: 0.5148
# Epoch 33, CIFAR-10 Batch 3:  Cost :0.80704, Accuracy on Training 0.7250 -Validation Accuracy: 0.5190
# Epoch 33, CIFAR-10 Batch 4:  Cost :0.97180, Accuracy on Training 0.6250 -Validation Accuracy: 0.5118
# Epoch 33, CIFAR-10 Batch 5:  Cost :0.94904, Accuracy on Training 0.6750 -Validation Accuracy: 0.5122
# Epoch 34, CIFAR-10 Batch 1:  Cost :0.95841, Accuracy on Training 0.6750 -Validation Accuracy: 0.5052
# Epoch 34, CIFAR-10 Batch 2:  Cost :0.93114, Accuracy on Training 0.5750 -Validation Accuracy: 0.5214
# Epoch 34, CIFAR-10 Batch 3:  Cost :0.83970, Accuracy on Training 0.7000 -Validation Accuracy: 0.5108
# Epoch 34, CIFAR-10 Batch 4:  Cost :1.00199, Accuracy on Training 0.6000 -Validation Accuracy: 0.5126
# Epoch 34, CIFAR-10 Batch 5:  Cost :0.95282, Accuracy on Training 0.7250 -Validation Accuracy: 0.5160
# Epoch 35, CIFAR-10 Batch 1:  Cost :0.97154, Accuracy on Training 0.7000 -Validation Accuracy: 0.5016
# Epoch 35, CIFAR-10 Batch 2:  Cost :0.93385, Accuracy on Training 0.5500 -Validation Accuracy: 0.5174
# Epoch 35, CIFAR-10 Batch 3:  Cost :0.85492, Accuracy on Training 0.7250 -Validation Accuracy: 0.4966
# Epoch 35, CIFAR-10 Batch 4:  Cost :0.97048, Accuracy on Training 0.6500 -Validation Accuracy: 0.5192
# Epoch 35, CIFAR-10 Batch 5:  Cost :0.94228, Accuracy on Training 0.7250 -Validation Accuracy: 0.5166
# Epoch 36, CIFAR-10 Batch 1:  Cost :1.00787, Accuracy on Training 0.6750 -Validation Accuracy: 0.4734
# Epoch 36, CIFAR-10 Batch 2:  Cost :0.90411, Accuracy on Training 0.6250 -Validation Accuracy: 0.5242
# Epoch 36, CIFAR-10 Batch 3:  Cost :0.80587, Accuracy on Training 0.7500 -Validation Accuracy: 0.5132
# Epoch 36, CIFAR-10 Batch 4:  Cost :0.94184, Accuracy on Training 0.6500 -Validation Accuracy: 0.5216
# Epoch 36, CIFAR-10 Batch 5:  Cost :0.89983, Accuracy on Training 0.7000 -Validation Accuracy: 0.5150
# Epoch 37, CIFAR-10 Batch 1:  Cost :0.93609, Accuracy on Training 0.6500 -Validation Accuracy: 0.5022
# Epoch 37, CIFAR-10 Batch 2:  Cost :0.98798, Accuracy on Training 0.5750 -Validation Accuracy: 0.5040
# Epoch 37, CIFAR-10 Batch 3:  Cost :0.82932, Accuracy on Training 0.7000 -Validation Accuracy: 0.5020
# Epoch 37, CIFAR-10 Batch 4:  Cost :0.95790, Accuracy on Training 0.7250 -Validation Accuracy: 0.5170
# Epoch 37, CIFAR-10 Batch 5:  Cost :0.90132, Accuracy on Training 0.6750 -Validation Accuracy: 0.5212
# Epoch 38, CIFAR-10 Batch 1:  Cost :0.94296, Accuracy on Training 0.6250 -Validation Accuracy: 0.5104
# Epoch 38, CIFAR-10 Batch 2:  Cost :0.90600, Accuracy on Training 0.6000 -Validation Accuracy: 0.5200
# Epoch 38, CIFAR-10 Batch 3:  Cost :0.80321, Accuracy on Training 0.6750 -Validation Accuracy: 0.5074
# Epoch 38, CIFAR-10 Batch 4:  Cost :0.93563, Accuracy on Training 0.7000 -Validation Accuracy: 0.5070
# Epoch 38, CIFAR-10 Batch 5:  Cost :0.88350, Accuracy on Training 0.7750 -Validation Accuracy: 0.5216
# Epoch 39, CIFAR-10 Batch 1:  Cost :0.95205, Accuracy on Training 0.6750 -Validation Accuracy: 0.4962
# Epoch 39, CIFAR-10 Batch 2:  Cost :0.94317, Accuracy on Training 0.5750 -Validation Accuracy: 0.5172
# Epoch 39, CIFAR-10 Batch 3:  Cost :0.79104, Accuracy on Training 0.7750 -Validation Accuracy: 0.5058
# Epoch 39, CIFAR-10 Batch 4:  Cost :0.92093, Accuracy on Training 0.7250 -Validation Accuracy: 0.5206
# Epoch 39, CIFAR-10 Batch 5:  Cost :0.87540, Accuracy on Training 0.7500 -Validation Accuracy: 0.5170
# Epoch 40, CIFAR-10 Batch 1:  Cost :0.86024, Accuracy on Training 0.6500 -Validation Accuracy: 0.5072
# Epoch 40, CIFAR-10 Batch 2:  Cost :0.88198, Accuracy on Training 0.6250 -Validation Accuracy: 0.5206
# Epoch 40, CIFAR-10 Batch 3:  Cost :0.76947, Accuracy on Training 0.7000 -Validation Accuracy: 0.5242
# Epoch 40, CIFAR-10 Batch 4:  Cost :0.92294, Accuracy on Training 0.7000 -Validation Accuracy: 0.4924
# Epoch 40, CIFAR-10 Batch 5:  Cost :0.88440, Accuracy on Training 0.6250 -Validation Accuracy: 0.5002
# Epoch 41, CIFAR-10 Batch 1:  Cost :0.89403, Accuracy on Training 0.6500 -Validation Accuracy: 0.5084
# Epoch 41, CIFAR-10 Batch 2:  Cost :0.89050, Accuracy on Training 0.6250 -Validation Accuracy: 0.5256
# Epoch 41, CIFAR-10 Batch 3:  Cost :0.77877, Accuracy on Training 0.6750 -Validation Accuracy: 0.5210
# Epoch 41, CIFAR-10 Batch 4:  Cost :0.88585, Accuracy on Training 0.6250 -Validation Accuracy: 0.5158
# Epoch 41, CIFAR-10 Batch 5:  Cost :0.84442, Accuracy on Training 0.7750 -Validation Accuracy: 0.5288
# Epoch 42, CIFAR-10 Batch 1:  Cost :0.87810, Accuracy on Training 0.6750 -Validation Accuracy: 0.5172
# Epoch 42, CIFAR-10 Batch 2:  Cost :0.88076, Accuracy on Training 0.6500 -Validation Accuracy: 0.5248
# Epoch 42, CIFAR-10 Batch 3:  Cost :0.77316, Accuracy on Training 0.7000 -Validation Accuracy: 0.5254
# Epoch 42, CIFAR-10 Batch 4:  Cost :0.90676, Accuracy on Training 0.7000 -Validation Accuracy: 0.5248
# Epoch 42, CIFAR-10 Batch 5:  Cost :0.83798, Accuracy on Training 0.7000 -Validation Accuracy: 0.5158
# Epoch 43, CIFAR-10 Batch 1:  Cost :0.85602, Accuracy on Training 0.7250 -Validation Accuracy: 0.5084
# Epoch 43, CIFAR-10 Batch 2:  Cost :0.89656, Accuracy on Training 0.6000 -Validation Accuracy: 0.5090
# Epoch 43, CIFAR-10 Batch 3:  Cost :0.77732, Accuracy on Training 0.6750 -Validation Accuracy: 0.5120
# Epoch 43, CIFAR-10 Batch 4:  Cost :0.85680, Accuracy on Training 0.7250 -Validation Accuracy: 0.5322
# Epoch 43, CIFAR-10 Batch 5:  Cost :0.90505, Accuracy on Training 0.6500 -Validation Accuracy: 0.5166
# Epoch 44, CIFAR-10 Batch 1:  Cost :0.88963, Accuracy on Training 0.6750 -Validation Accuracy: 0.4882
# Epoch 44, CIFAR-10 Batch 2:  Cost :0.85523, Accuracy on Training 0.6000 -Validation Accuracy: 0.5322
# Epoch 44, CIFAR-10 Batch 3:  Cost :0.74315, Accuracy on Training 0.6750 -Validation Accuracy: 0.5212
# Epoch 44, CIFAR-10 Batch 4:  Cost :0.87523, Accuracy on Training 0.7500 -Validation Accuracy: 0.5232
# Epoch 44, CIFAR-10 Batch 5:  Cost :0.89285, Accuracy on Training 0.7000 -Validation Accuracy: 0.5142
# Epoch 45, CIFAR-10 Batch 1:  Cost :0.89433, Accuracy on Training 0.6750 -Validation Accuracy: 0.4970
# Epoch 45, CIFAR-10 Batch 2:  Cost :0.84150, Accuracy on Training 0.6250 -Validation Accuracy: 0.5268
# Epoch 45, CIFAR-10 Batch 3:  Cost :0.78076, Accuracy on Training 0.6750 -Validation Accuracy: 0.5102
# Epoch 45, CIFAR-10 Batch 4:  Cost :0.87529, Accuracy on Training 0.7500 -Validation Accuracy: 0.5280
# Epoch 45, CIFAR-10 Batch 5:  Cost :0.84915, Accuracy on Training 0.7500 -Validation Accuracy: 0.5186
# Epoch 46, CIFAR-10 Batch 1:  Cost :0.88984, Accuracy on Training 0.6500 -Validation Accuracy: 0.5186
# Epoch 46, CIFAR-10 Batch 2:  Cost :0.78263, Accuracy on Training 0.6250 -Validation Accuracy: 0.5344
# Epoch 46, CIFAR-10 Batch 3:  Cost :0.73161, Accuracy on Training 0.7250 -Validation Accuracy: 0.5292
# Epoch 46, CIFAR-10 Batch 4:  Cost :0.86668, Accuracy on Training 0.7000 -Validation Accuracy: 0.5240
# Epoch 46, CIFAR-10 Batch 5:  Cost :0.85933, Accuracy on Training 0.7250 -Validation Accuracy: 0.5108
# Epoch 47, CIFAR-10 Batch 1:  Cost :0.87836, Accuracy on Training 0.6750 -Validation Accuracy: 0.5100
# Epoch 47, CIFAR-10 Batch 2:  Cost :0.78257, Accuracy on Training 0.6250 -Validation Accuracy: 0.5344
# Epoch 47, CIFAR-10 Batch 3:  Cost :0.71832, Accuracy on Training 0.7250 -Validation Accuracy: 0.5144
# Epoch 47, CIFAR-10 Batch 4:  Cost :0.86560, Accuracy on Training 0.6750 -Validation Accuracy: 0.5228
# Epoch 47, CIFAR-10 Batch 5:  Cost :0.85450, Accuracy on Training 0.7250 -Validation Accuracy: 0.5132
# Epoch 48, CIFAR-10 Batch 1:  Cost :0.80702, Accuracy on Training 0.6750 -Validation Accuracy: 0.5112
# Epoch 48, CIFAR-10 Batch 2:  Cost :0.78791, Accuracy on Training 0.6250 -Validation Accuracy: 0.5288
# Epoch 48, CIFAR-10 Batch 3:  Cost :0.71573, Accuracy on Training 0.6750 -Validation Accuracy: 0.5092
# Epoch 48, CIFAR-10 Batch 4:  Cost :0.84844, Accuracy on Training 0.6750 -Validation Accuracy: 0.5168
# Epoch 48, CIFAR-10 Batch 5:  Cost :0.86949, Accuracy on Training 0.7000 -Validation Accuracy: 0.5092
# Epoch 49, CIFAR-10 Batch 1:  Cost :0.81383, Accuracy on Training 0.6750 -Validation Accuracy: 0.5182
# Epoch 49, CIFAR-10 Batch 2:  Cost :0.78503, Accuracy on Training 0.6500 -Validation Accuracy: 0.5366
# Epoch 49, CIFAR-10 Batch 3:  Cost :0.69309, Accuracy on Training 0.7000 -Validation Accuracy: 0.5214
# Epoch 49, CIFAR-10 Batch 4:  Cost :0.80260, Accuracy on Training 0.7500 -Validation Accuracy: 0.5250
# Epoch 49, CIFAR-10 Batch 5:  Cost :0.82416, Accuracy on Training 0.6500 -Validation Accuracy: 0.5090
# Epoch 50, CIFAR-10 Batch 1:  Cost :0.80063, Accuracy on Training 0.6500 -Validation Accuracy: 0.5232
# Epoch 50, CIFAR-10 Batch 2:  Cost :0.79041, Accuracy on Training 0.6000 -Validation Accuracy: 0.5292
# Epoch 50, CIFAR-10 Batch 3:  Cost :0.77935, Accuracy on Training 0.6750 -Validation Accuracy: 0.5162
# Epoch 50, CIFAR-10 Batch 4:  Cost :0.82879, Accuracy on Training 0.7250 -Validation Accuracy: 0.5282
# Epoch 50, CIFAR-10 Batch 5:  Cost :0.81186, Accuracy on Training 0.7250 -Validation Accuracy: 0.5158

# %% [markdown]
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
# ToDO
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        # ToDO
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0') 
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        # ToDO
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.50751953125
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
